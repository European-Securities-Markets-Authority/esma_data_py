# %%
# !pip install git+https://github.com/European-Securities-Markets-Authority/esma_data_py.git
# !pip install pandas

# %%
from  esma_data_py import EsmaDataLoader
import os
import pandas as pd

# %%
edl = EsmaDataLoader(creation_date_from='2025-11-20')
df = edl.load_latest_files()
df = df.query("Mthdlgy == 'YEAR'").query("FrDt >= '2024-01-01'")

# %%
df['AvrgTxVal'] = pd.to_numeric(df['AvrgTxVal'])
df[df['AvrgTxVal'] <= 20000]
